# %%
# !pip install scikit-learn pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.9.0)
# Requirement already satisfied: pandas in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.5)
# Requirement already satisfied: matplotlib in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.10.9)
# Requirement already satisfied: seaborn in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.13.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\rajpu\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()

# %%
df = pd.DataFrame(data = data.data , columns = data.feature_names)

# %%
df['Price'] = data.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# Price         0
# dtype: int64

# %%
plt.hist(df['Price'],bins=50)
plt.xlabel('Price')
plt.title('Price Distribution')
plt.show()

# %% [markdown]
# Observation 1: Most house prices are concentrated between $100k-$300k
# Observation 2: Distribution is right-skewed — more cheap houses than expensive ones
# Observation 3: There is an artificial cap at $500k — houses above this price
# were all recorded as 5.0, which may affect model accuracy

# %%
sns.heatmap(df.corr(),annot=True)
plt.title('Feature Correlation Heatmap')
plt.show()

# %% [markdown]
# Observation 4: MedInc has highest correlation with Price (0.69) —
# richer neighborhoods have more expensive houses. Makes sense.
#
# Observation 5: Latitude and Longitude have low correlation with Price
# individually but location still matters — we'll keep them.
#
# Observation 6: AveRooms and AveBedrms are highly correlated with each other.
# This is called multicollinearity. They carry similar information.

# %%
plt.scatter(x=df['MedInc'] , y=df['Price'])
plt.xlabel('Income')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Observation 7: Clear positive relationship between MedInc and Price.
# Higher income neighborhoods = more expensive houses.
# The flat line at Price=5.0 confirms the artificial price cap we noticed earlier.

# %%
plt.scatter(x=df['HouseAge'] , y=df['Price'])
plt.xlabel('Age of House')
plt.ylabel('Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observation 8: House age has very weak relationship with Price.
# Age alone is not a good predictor of house price.
# MedInc is clearly the most important feature so far.

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2 , random_state = 20)

# %%
X_train.shape
# Out:
# (16512, 8)

# %%
y_train.shape
# Out:
# (16512,)

# %%
X_test.shape
# Out:
# (4128, 8)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
pipeline_steps=[
        ('scaler' , StandardScaler()),
        ('model' , LinearRegression())
]

# %%
housing_pipeline= Pipeline(pipeline_steps)

# %%
housing_pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LinearRegression())])

# %%
y_pred = housing_pipeline.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,  mean_squared_error , root_mean_squared_error , r2_score

# %%
print("MSE", mean_squared_error(y_test,y_pred))
print("MAE" , mean_absolute_error(y_test,y_pred))
print("RMSE", root_mean_squared_error(y_test,y_pred))
print("r2Score",r2_score(y_test,y_pred))
# Out:
# MSE 0.5410055769085322
# MAE 0.5409622217186032
# RMSE 0.7355308130245342
# r2Score 0.6121654293404898

# %% [markdown]
# Model Results:
# - R² Score: 0.61 — model explains 61% of price variation
# - RMSE: 0.73 — average prediction error of $73,000
# - Linear Regression is a baseline model
# - Score can be improved with better feature engineering
#   or more powerful models like Random Forest

# %%
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted House Prices')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted House Prices')
